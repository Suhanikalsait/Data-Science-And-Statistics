# %% [markdown]
#  # Creation of Array

# %%
# Exp5

# %%
# Aim - Creation of Array (1D,2D and Multidimennsional array) using numpy

# %%
# Name: Huzaif Khan
# Roll no: 23
# Section: B
# Subject: ET-I

# %%
import numpy as np

# %%
arr=np.array([50,62,80,26,47,19])

# %%
arr
# Out:
# array([50, 62, 80, 26, 47, 19])

# %%
arr2=np.array([[50,62,80,26,47,19],[40,56,20,41,38,77]])

# %%
arr2
# Out:
# array([[50, 62, 80, 26, 47, 19],
#        [40, 56, 20, 41, 38, 77]])

# %%
arr3=np.array([[50,62,80,26,47,19],[40,56,20,41,38,77],[10,45,91,54,27,38]])

# %%
arr3
# Out:
# array([[50, 62, 80, 26, 47, 19],
#        [40, 56, 20, 41, 38, 77],
#        [10, 45, 91, 54, 27, 38]])
